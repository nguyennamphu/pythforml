# %% [markdown]
# ## Chapter 4 - Exercise 2: Hãy thực hiện những yêu cầu liên quan tới Data Frame, và đối chiếu với kết quả cho trước

# %%
import numpy as np
import pandas as pd

# %%
# Câu 1: Cho dictionary như sau: 
dic_1 = {'X':[78,85,96,80,86], 'Y':[84,94,89,83,86], 'Z':[86,97,96,72,83]}

# Tạo dataframe df1 từ dic_1
df1 = pd.DataFrame(dic_1)
# In nội dung của dataframe df1
df1
# Out:
#     X   Y   Z
# 0  78  84  86
# 1  85  94  97
# 2  96  89  96
# 3  80  83  72
# 4  86  86  83

# %% [markdown]
# <details>
#   <summary>Nhấn vào đây để xem kết quả!</summary>
#   <div>
# <style scoped="">
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>X</th>
#       <th>Y</th>
#       <th>Z</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>78</td>
#       <td>84</td>
#       <td>86</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>85</td>
#       <td>94</td>
#       <td>97</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>96</td>
#       <td>89</td>
#       <td>96</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>80</td>
#       <td>83</td>
#       <td>72</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>86</td>
#       <td>86</td>
#       <td>83</td>
#     </tr>
#   </tbody>
# </table>
# </div>
#
# </details>

# %%
# Câu 2:
# Cho dictionary exam_data như sau:
exam_data  = {'name': ['Anastasia', 'Dima', 'Katherine', 'James', 'Emily', 'Michael', 'Matthew', 'Laura', 'Kevin', 'Jonas'],
        'score': [12.5, 9, 16.5, np.nan, 9, 20, 14.5,np.nan, 8, 19],
        'attempts': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
        'qualify': ['yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes']}

# Cho list labels như sau:
labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

# %%
# Câu 2a: Tạo dataframe df2 từ exam_data, với index của dataframe là lables
df2 = pd.DataFrame(exam_data, index=labels)
# In nội dung của dataframe df2
df2
# Out:
#         name  score  attempts qualify
# a  Anastasia   12.5         1     yes
# b       Dima    9.0         3      no
# c  Katherine   16.5         2     yes
# d      James    NaN         3      no
# e      Emily    9.0         2      no
# f    Michael   20.0         3     yes
# g    Matthew   14.5         1     yes
# h      Laura    NaN         1      no
# i      Kevin    8.0         2      no
# j      Jonas   19.0         1     yes

# %% [markdown]
# <details>
#   <summary>Nhấn vào đây để xem kết quả!</summary>
#   <div>
# <style scoped="">
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>name</th>
#       <th>score</th>
#       <th>attempts</th>
#       <th>qualify</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>a</th>
#       <td>Anastasia</td>
#       <td>12.5</td>
#       <td>1</td>
#       <td>yes</td>
#     </tr>
#     <tr>
#       <th>b</th>
#       <td>Dima</td>
#       <td>9.0</td>
#       <td>3</td>
#       <td>no</td>
#     </tr>
#     <tr>
#       <th>c</th>
#       <td>Katherine</td>
#       <td>16.5</td>
#       <td>2</td>
#       <td>yes</td>
#     </tr>
#     <tr>
#       <th>d</th>
#       <td>James</td>
#       <td>NaN</td>
#       <td>3</td>
#       <td>no</td>
#     </tr>
#     <tr>
#       <th>e</th>
#       <td>Emily</td>
#       <td>9.0</td>
#       <td>2</td>
#       <td>no</td>
#     </tr>
#     <tr>
#       <th>f</th>
#       <td>Michael</td>
#       <td>20.0</td>
#       <td>3</td>
#       <td>yes</td>
#     </tr>
#     <tr>
#       <th>g</th>
#       <td>Matthew</td>
#       <td>14.5</td>
#       <td>1</td>
#       <td>yes</td>
#     </tr>
#     <tr>
#       <th>h</th>
#       <td>Laura</td>
#       <td>NaN</td>
#       <td>1</td>
#       <td>no</td>
#     </tr>
#     <tr>
#       <th>i</th>
#       <td>Kevin</td>
#       <td>8.0</td>
#       <td>2</td>
#       <td>no</td>
#     </tr>
#     <tr>
#       <th>j</th>
#       <td>Jonas</td>
#       <td>19.0</td>
#       <td>1</td>
#       <td>yes</td>
#     </tr>
#   </tbody>
# </table>
# </div>
#
# </details>

# %%
# Câu 2b: Xem thông tin (info()) của dataframe df2
df2.info
# Out:
# <bound method DataFrame.info of         name  score  attempts qualify
# a  Anastasia   12.5         1     yes
# b       Dima    9.0         3      no
# c  Katherine   16.5         2     yes
# d      James    NaN         3      no
# e      Emily    9.0         2      no
# f    Michael   20.0         3     yes
# g    Matthew   14.5         1     yes
# h      Laura    NaN         1      no
# i      Kevin    8.0         2      no
# j      Jonas   19.0         1     yes>

# %% [markdown]
# <details>
#   <summary>Nhấn vào đây để xem kết quả!</summary>
#   <pre>&lt;class 'pandas.core.frame.DataFrame'&gt;
# Index: 10 entries, a to j
# Data columns (total 4 columns):
# name        10 non-null object
# score       8 non-null float64
# attempts    10 non-null int64
# qualify     10 non-null object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 400.0+ bytes
# </pre>
#
# </details>

# %%
# Câu 3: Tạo dataframe df3 từ df2, chỉ chứa 2 cột là name và score
df3 = pd.DataFrame(df2, columns=["name", "score"])
# Xem kiểu dữ liệu (type) và kích thước (shape) của df3
type(df3)
df3.shape
# Hiển thị các dòng dữ liệu đầu tiên (head) của df3
df3.head()
# Out:
#         name  score
# a  Anastasia   12.5
# b       Dima    9.0
# c  Katherine   16.5
# d      James    NaN
# e      Emily    9.0

# %% [markdown]
# <details>
#   <summary>Nhấn vào đây để xem kết quả!</summary>
#   <pre>&lt;class 'pandas.core.frame.DataFrame'&gt;
# (10, 2)
# </pre>
#
#   <div class="output_subarea output_html rendered_html output_result"><div>
# <style scoped="">
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>name</th>
#       <th>score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>a</th>
#       <td>Anastasia</td>
#       <td>12.5</td>
#     </tr>
#     <tr>
#       <th>b</th>
#       <td>Dima</td>
#       <td>9.0</td>
#     </tr>
#     <tr>
#       <th>c</th>
#       <td>Katherine</td>
#       <td>16.5</td>
#     </tr>
#     <tr>
#       <th>d</th>
#       <td>James</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>e</th>
#       <td>Emily</td>
#       <td>9.0</td>
#     </tr>
#   </tbody>
# </table>
# </div></div>
#
# </details>

# %%
# Câu 4: Hiển thị thông tin thống kê chung (describe) của dataframe df2
df2.describe()
# Out:
#            score   attempts
# count   8.000000  10.000000
# mean   13.562500   1.900000
# std     4.693746   0.875595
# min     8.000000   1.000000
# 25%     9.000000   1.000000
# 50%    13.500000   2.000000
# 75%    17.125000   2.750000
# max    20.000000   3.000000

# %% [markdown]
# <details>
#   <summary>Nhấn vào đây để xem kết quả!</summary>
#   <div>
# <style scoped="">
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>name</th>
#       <th>score</th>
#       <th>attempts</th>
#       <th>qualify</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>10</td>
#       <td>8.000000</td>
#       <td>10.000000</td>
#       <td>10</td>
#     </tr>
#     <tr>
#       <th>unique</th>
#       <td>10</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>top</th>
#       <td>Matthew</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>yes</td>
#     </tr>
#     <tr>
#       <th>freq</th>
#       <td>1</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>mean</th>
#       <td>NaN</td>
#       <td>13.562500</td>
#       <td>1.900000</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>std</th>
#       <td>NaN</td>
#       <td>4.693746</td>
#       <td>0.875595</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>min</th>
#       <td>NaN</td>
#       <td>8.000000</td>
#       <td>1.000000</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>25%</th>
#       <td>NaN</td>
#       <td>9.000000</td>
#       <td>1.000000</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>50%</th>
#       <td>NaN</td>
#       <td>13.500000</td>
#       <td>2.000000</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>75%</th>
#       <td>NaN</td>
#       <td>17.125000</td>
#       <td>2.750000</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>max</th>
#       <td>NaN</td>
#       <td>20.000000</td>
#       <td>3.000000</td>
#       <td>NaN</td>
#     </tr>
#   </tbody>
# </table>
# </div>
#
# </details>

# %%
# Câu 5: Tạo dataframe df4 từ df2, chỉ chứa 2 cột là name và score, và chỉ có các dòng 1, 3, 5, 6
df4 = pd.DataFrame(df2, index=['b', 'd', 'f', 'g'], columns=["name", "score"])
# In nội dung của dataframe df4
df4
# Out:
#       name  score
# b     Dima    9.0
# d    James    NaN
# f  Michael   20.0
# g  Matthew   14.5

# %% [markdown]
# <details>
#   <summary>Nhấn vào đây để xem kết quả!</summary>
#   <div>
# <style scoped="">
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>name</th>
#       <th>score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>b</th>
#       <td>Dima</td>
#       <td>9.0</td>
#     </tr>
#     <tr>
#       <th>d</th>
#       <td>James</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>f</th>
#       <td>Michael</td>
#       <td>20.0</td>
#     </tr>
#     <tr>
#       <th>g</th>
#       <td>Matthew</td>
#       <td>14.5</td>
#     </tr>
#   </tbody>
# </table>
# </div>
#
# </details>

# %%
# Câu 6: Từ dataframe df2, in các dòng có dữ liệu score bị null
df2[np.isnan(df2["score"])]
# Out:
#     name  score  attempts qualify
# d  James    NaN         3      no
# h  Laura    NaN         1      no

# %% [markdown]
# <details>
#   <summary>Nhấn vào đây để xem kết quả!</summary>
#   <div>
# <style scoped="">
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>name</th>
#       <th>score</th>
#       <th>attempts</th>
#       <th>qualify</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>d</th>
#       <td>James</td>
#       <td>NaN</td>
#       <td>3</td>
#       <td>no</td>
#     </tr>
#     <tr>
#       <th>h</th>
#       <td>Laura</td>
#       <td>NaN</td>
#       <td>1</td>
#       <td>no</td>
#     </tr>
#   </tbody>
# </table>
# </div>
#
# </details>

# %%
# Câu 7: Từ dataframe df2, in các dòng có score > 15 và <=20
df2[(df2["score"] > 15) & (df2["score"] <= 20)]
# Out:
#         name  score  attempts qualify
# c  Katherine   16.5         2     yes
# f    Michael   20.0         3     yes
# j      Jonas   19.0         1     yes

# %% [markdown]
# <details>
#   <summary>Nhấn vào đây để xem kết quả!</summary>
#   <div>
# <style scoped="">
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>name</th>
#       <th>score</th>
#       <th>attempts</th>
#       <th>qualify</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>c</th>
#       <td>Katherine</td>
#       <td>16.5</td>
#       <td>2</td>
#       <td>yes</td>
#     </tr>
#     <tr>
#       <th>f</th>
#       <td>Michael</td>
#       <td>20.0</td>
#       <td>3</td>
#       <td>yes</td>
#     </tr>
#     <tr>
#       <th>j</th>
#       <td>Jonas</td>
#       <td>19.0</td>
#       <td>1</td>
#       <td>yes</td>
#     </tr>
#   </tbody>
# </table>
# </div>
#
# </details>

# %%
# Câu 8: Cập nhật điểm (score) ở dòng 'd' thành 18
df2.loc['d', "score"] = 18

# %% [markdown]
# <details>
#   <summary>Nhấn vào đây để xem kết quả!</summary>
#   <div>
# <style scoped="">
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>name</th>
#       <th>score</th>
#       <th>attempts</th>
#       <th>qualify</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>a</th>
#       <td>Anastasia</td>
#       <td>12.5</td>
#       <td>1</td>
#       <td>yes</td>
#     </tr>
#     <tr>
#       <th>b</th>
#       <td>Dima</td>
#       <td>9.0</td>
#       <td>3</td>
#       <td>no</td>
#     </tr>
#     <tr>
#       <th>c</th>
#       <td>Katherine</td>
#       <td>16.5</td>
#       <td>2</td>
#       <td>yes</td>
#     </tr>
#     <tr>
#       <th>d</th>
#       <td>James</td>
#       <td>18.0</td>
#       <td>3</td>
#       <td>no</td>
#     </tr>
#     <tr>
#       <th>e</th>
#       <td>Emily</td>
#       <td>9.0</td>
#       <td>2</td>
#       <td>no</td>
#     </tr>
#   </tbody>
# </table>
# </div>
#
# </details>

# %%
# Câu 9: Cho biết điểm (score) nào có tần suất xuất hiện nhiều nhất trong df2, và in ra những dòng có điểm là tần suất xuất hiện nhiều nhất 
most_the_score = df2["score"].value_counts().idxmax()
df2[df2["score"] == most_the_score]


# Cho biết có bao nhiêu dòng thỏa điều kiện?
# Out:
#     name  score  attempts qualify
# b   Dima    9.0         3      no
# e  Emily    9.0         2      no

# %% [markdown]
# <details>
#   <summary>Nhấn vào đây để xem kết quả!</summary>
#   <pre>9.0
# </pre>
#
#   <div>
# <style scoped="">
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>name</th>
#       <th>score</th>
#       <th>attempts</th>
#       <th>qualify</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>b</th>
#       <td>Dima</td>
#       <td>9.0</td>
#       <td>3</td>
#       <td>no</td>
#     </tr>
#     <tr>
#       <th>e</th>
#       <td>Emily</td>
#       <td>9.0</td>
#       <td>2</td>
#       <td>no</td>
#     </tr>
#   </tbody>
# </table>
# </div>
#
# </details>

# %%
# Câu 10: Thêm dòng k có nội dung như sau: ['Suresh', 15.5, 1, 'yes'] vào df2
df2.loc['k'] = ['Suresh', 15.5, 1, 'yes']
# Hiển thị 5 dòng cuối cùng (tail) của df2.
df2.tail()
# Out:
#       name  score  attempts qualify
# g  Matthew   14.5         1     yes
# h    Laura    NaN         1      no
# i    Kevin    8.0         2      no
# j    Jonas   19.0         1     yes
# k   Suresh   15.5         1     yes

# %% [markdown]
# <details>
#   <summary>Nhấn vào đây để xem kết quả!</summary>
#   <div>
# <style scoped="">
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>name</th>
#       <th>score</th>
#       <th>attempts</th>
#       <th>qualify</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>g</th>
#       <td>Matthew</td>
#       <td>14.5</td>
#       <td>1</td>
#       <td>yes</td>
#     </tr>
#     <tr>
#       <th>h</th>
#       <td>Laura</td>
#       <td>NaN</td>
#       <td>1</td>
#       <td>no</td>
#     </tr>
#     <tr>
#       <th>i</th>
#       <td>Kevin</td>
#       <td>8.0</td>
#       <td>2</td>
#       <td>no</td>
#     </tr>
#     <tr>
#       <th>j</th>
#       <td>Jonas</td>
#       <td>19.0</td>
#       <td>1</td>
#       <td>yes</td>
#     </tr>
#     <tr>
#       <th>k</th>
#       <td>Suresh</td>
#       <td>15.5</td>
#       <td>1</td>
#       <td>yes</td>
#     </tr>
#   </tbody>
# </table>
# </div>
#
# </details>

# %%
# Câu 11a: Thêm dòng l có nội dung như sau: ['Janny', 12.5, 2, 'yes'] vào df2. 
df2.loc['l'] = ['Janny', 12.5, 2, 'yes']
# Hiển thị 5 dòng cuối cùng (tail) của df2.
df2.tail()
# Out:
#      name  score  attempts qualify
# h   Laura    NaN         1      no
# i   Kevin    8.0         2      no
# j   Jonas   19.0         1     yes
# k  Suresh   15.5         1     yes
# l   Janny   12.5         2     yes

# %% [markdown]
# <details>
#   <summary>Nhấn vào đây để xem kết quả!</summary>
#   <div>
# <style scoped="">
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>name</th>
#       <th>score</th>
#       <th>attempts</th>
#       <th>qualify</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>h</th>
#       <td>Laura</td>
#       <td>NaN</td>
#       <td>1</td>
#       <td>no</td>
#     </tr>
#     <tr>
#       <th>i</th>
#       <td>Kevin</td>
#       <td>8.0</td>
#       <td>2</td>
#       <td>no</td>
#     </tr>
#     <tr>
#       <th>j</th>
#       <td>Jonas</td>
#       <td>19.0</td>
#       <td>1</td>
#       <td>yes</td>
#     </tr>
#     <tr>
#       <th>k</th>
#       <td>Suresh</td>
#       <td>15.5</td>
#       <td>1</td>
#       <td>yes</td>
#     </tr>
#     <tr>
#       <th>l</th>
#       <td>Janny</td>
#       <td>12.5</td>
#       <td>2</td>
#       <td>yes</td>
#     </tr>
#   </tbody>
# </table>
# </div>
#
# </details>

# %%
# Câu 11b: Xóa bỏ dòng l của df2. 

# Hiển thị lại 5 dòng cuối cùng (tail) của df2.
df2 = df2.drop("l", axis=0)
df2.tail()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-72-e1a012a33cb5> in <module>
#       2
#       3 # Hiển thị lại 5 dòng cuối cùng (tail) của df2.
# ----> 4 df2 = df2.drop("l", axis=0)
#       5 df2.tail()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'drop'

# %% [markdown]
# <details>
#   <summary>Nhấn vào đây để xem kết quả!</summary>
#   <div>
# <style scoped="">
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>name</th>
#       <th>score</th>
#       <th>attempts</th>
#       <th>qualify</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>g</th>
#       <td>Matthew</td>
#       <td>14.5</td>
#       <td>1</td>
#       <td>yes</td>
#     </tr>
#     <tr>
#       <th>h</th>
#       <td>Laura</td>
#       <td>NaN</td>
#       <td>1</td>
#       <td>no</td>
#     </tr>
#     <tr>
#       <th>i</th>
#       <td>Kevin</td>
#       <td>8.0</td>
#       <td>2</td>
#       <td>no</td>
#     </tr>
#     <tr>
#       <th>j</th>
#       <td>Jonas</td>
#       <td>19.0</td>
#       <td>1</td>
#       <td>yes</td>
#     </tr>
#     <tr>
#       <th>k</th>
#       <td>Suresh</td>
#       <td>15.5</td>
#       <td>1</td>
#       <td>yes</td>
#     </tr>
#   </tbody>
# </table>
# </div>
#
# </details>

# %%
# Câu 12: Sắp xếp df2 tăng dần theo điểm (score)
df2 = df2.sort_values("score", axis = 0, ascending = True)
df2
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-71-1d4c225c735b> in <module>
#       1 # Câu 12: Sắp xếp df2 tăng dần theo điểm (score)
# ----> 2 df2 = df2.sort_values("score", axis = 0, ascending = True)
#       3 df2
#
# AttributeError: 'numpy.ndarray' object has no attribute 'sort_values'

# %% [markdown]
# <details>
#   <summary>Nhấn vào đây để xem kết quả!</summary>
#   <div>
# <style scoped="">
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>name</th>
#       <th>score</th>
#       <th>attempts</th>
#       <th>qualify</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>i</th>
#       <td>Kevin</td>
#       <td>8.0</td>
#       <td>2</td>
#       <td>no</td>
#     </tr>
#     <tr>
#       <th>b</th>
#       <td>Dima</td>
#       <td>9.0</td>
#       <td>3</td>
#       <td>no</td>
#     </tr>
#     <tr>
#       <th>e</th>
#       <td>Emily</td>
#       <td>9.0</td>
#       <td>2</td>
#       <td>no</td>
#     </tr>
#     <tr>
#       <th>a</th>
#       <td>Anastasia</td>
#       <td>12.5</td>
#       <td>1</td>
#       <td>yes</td>
#     </tr>
#     <tr>
#       <th>g</th>
#       <td>Matthew</td>
#       <td>14.5</td>
#       <td>1</td>
#       <td>yes</td>
#     </tr>
#     <tr>
#       <th>k</th>
#       <td>Suresh</td>
#       <td>15.5</td>
#       <td>1</td>
#       <td>yes</td>
#     </tr>
#     <tr>
#       <th>c</th>
#       <td>Katherine</td>
#       <td>16.5</td>
#       <td>2</td>
#       <td>yes</td>
#     </tr>
#     <tr>
#       <th>d</th>
#       <td>James</td>
#       <td>18.0</td>
#       <td>3</td>
#       <td>no</td>
#     </tr>
#     <tr>
#       <th>j</th>
#       <td>Jonas</td>
#       <td>19.0</td>
#       <td>1</td>
#       <td>yes</td>
#     </tr>
#     <tr>
#       <th>f</th>
#       <td>Michael</td>
#       <td>20.0</td>
#       <td>3</td>
#       <td>yes</td>
#     </tr>
#     <tr>
#       <th>h</th>
#       <td>Laura</td>
#       <td>NaN</td>
#       <td>1</td>
#       <td>no</td>
#     </tr>
#   </tbody>
# </table>
# </div>
#
# </details>

# %%
# Câu 13: Thêm cột result vào df2, 
# dựa vào dữ liệu của cột'score', nếu dòng nào có điểm >=10 thì giá trị của cột result = 1, ngược lại = 0
list_score = np.array((df2['score'] > 10) | (df2['score'] == 10))
list_score = np.where(list_score == False, 0, list_score)
df2['result'] = list_score
# In nội dung của dataframe df2
df2
# Out:
#         name  score  attempts qualify  result
# a  Anastasia   12.5         1     yes       1
# b       Dima    9.0         3      no       0
# c  Katherine   16.5         2     yes       1
# d      James    NaN         3      no       0
# e      Emily    9.0         2      no       0
# f    Michael   20.0         3     yes       1
# g    Matthew   14.5         1     yes       1
# h      Laura    NaN         1      no       0
# i      Kevin    8.0         2      no       0
# j      Jonas   19.0         1     yes       1

# %% [markdown]
# <details>
#   <summary>Nhấn vào đây để xem kết quả!</summary>
#   <div>
# <style scoped="">
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>name</th>
#       <th>score</th>
#       <th>attempts</th>
#       <th>qualify</th>
#       <th>result</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>i</th>
#       <td>Kevin</td>
#       <td>8.0</td>
#       <td>2</td>
#       <td>no</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>b</th>
#       <td>Dima</td>
#       <td>9.0</td>
#       <td>3</td>
#       <td>no</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>e</th>
#       <td>Emily</td>
#       <td>9.0</td>
#       <td>2</td>
#       <td>no</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>a</th>
#       <td>Anastasia</td>
#       <td>12.5</td>
#       <td>1</td>
#       <td>yes</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>g</th>
#       <td>Matthew</td>
#       <td>14.5</td>
#       <td>1</td>
#       <td>yes</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>k</th>
#       <td>Suresh</td>
#       <td>15.5</td>
#       <td>1</td>
#       <td>yes</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>c</th>
#       <td>Katherine</td>
#       <td>16.5</td>
#       <td>2</td>
#       <td>yes</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>d</th>
#       <td>James</td>
#       <td>18.0</td>
#       <td>3</td>
#       <td>no</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>j</th>
#       <td>Jonas</td>
#       <td>19.0</td>
#       <td>1</td>
#       <td>yes</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>f</th>
#       <td>Michael</td>
#       <td>20.0</td>
#       <td>3</td>
#       <td>yes</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>h</th>
#       <td>Laura</td>
#       <td>NaN</td>
#       <td>1</td>
#       <td>no</td>
#       <td>0</td>
#     </tr>
#   </tbody>
# </table>
# </div>
#
# </details>

# %%
# Câu 14: Trong df2, thay tên 'Emily' thành 'Samantha'
df2.replace("Emily", "Samantha",inplace=True)
# In lại nội dung của dataframe df2
df2
# Out:
#         name  score  attempts qualify  result
# a  Anastasia   12.5         1     yes       1
# b       Dima    9.0         3      no       0
# c  Katherine   16.5         2     yes       1
# d      James    NaN         3      no       0
# e   Samantha    9.0         2      no       0
# f    Michael   20.0         3     yes       1
# g    Matthew   14.5         1     yes       1
# h      Laura    NaN         1      no       0
# i      Kevin    8.0         2      no       0
# j      Jonas   19.0         1     yes       1

# %% [markdown]
# <details>
#   <summary>Nhấn vào đây để xem kết quả!</summary>
#   <div>
# <style scoped="">
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>name</th>
#       <th>score</th>
#       <th>attempts</th>
#       <th>qualify</th>
#       <th>result</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>i</th>
#       <td>Kevin</td>
#       <td>8.0</td>
#       <td>2</td>
#       <td>no</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>b</th>
#       <td>Dima</td>
#       <td>9.0</td>
#       <td>3</td>
#       <td>no</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>e</th>
#       <td>Samantha</td>
#       <td>9.0</td>
#       <td>2</td>
#       <td>no</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>a</th>
#       <td>Anastasia</td>
#       <td>12.5</td>
#       <td>1</td>
#       <td>yes</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>g</th>
#       <td>Matthew</td>
#       <td>14.5</td>
#       <td>1</td>
#       <td>yes</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>k</th>
#       <td>Suresh</td>
#       <td>15.5</td>
#       <td>1</td>
#       <td>yes</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>c</th>
#       <td>Katherine</td>
#       <td>16.5</td>
#       <td>2</td>
#       <td>yes</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>d</th>
#       <td>James</td>
#       <td>18.0</td>
#       <td>3</td>
#       <td>no</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>j</th>
#       <td>Jonas</td>
#       <td>19.0</td>
#       <td>1</td>
#       <td>yes</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>f</th>
#       <td>Michael</td>
#       <td>20.0</td>
#       <td>3</td>
#       <td>yes</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>h</th>
#       <td>Laura</td>
#       <td>NaN</td>
#       <td>1</td>
#       <td>no</td>
#       <td>0</td>
#     </tr>
#   </tbody>
# </table>
# </div>
#
# </details>

# %%
# Câu 15: Duyệt df2, in name, score, result: nếu nếu giá trị cột result = 1 thì in 'Pass', ngược lại thì in 'Fail'
for row in df2[['name', 'score', 'result']].values:
    if row[2] == 1:
        print('%s - Score: %s - Results: %s' %(row[0], row[1], 'Fail'))
    else:
        print('%s - Score: %s - Results: %s' %(row[0], row[1], 'Pass'))
# Out:
# Anastasia - Score: 12.5 - Results: Fail
# Dima - Score: 9.0 - Results: Pass
# Katherine - Score: 16.5 - Results: Fail
# James - Score: nan - Results: Pass
# Samantha - Score: 9.0 - Results: Pass
# Michael - Score: 20.0 - Results: Fail
# Matthew - Score: 14.5 - Results: Fail
# Laura - Score: nan - Results: Pass
# Kevin - Score: 8.0 - Results: Pass
# Jonas - Score: 19.0 - Results: Fail

# %% [markdown]
# <details>
#   <summary>Nhấn vào đây để xem kết quả!</summary>
#   <pre>Kevin  - Score: 8.0  - Result: Fail
# Dima  - Score: 9.0  - Result: Fail
# Samantha  - Score: 9.0  - Result: Fail
# Anastasia  - Score: 12.5  - Result: Pass
# Matthew  - Score: 14.5  - Result: Pass
# Suresh  - Score: 15.5  - Result: Pass
# Katherine  - Score: 16.5  - Result: Pass
# James  - Score: 18.0  - Result: Pass
# Jonas  - Score: 19.0  - Result: Pass
# Michael  - Score: 20.0  - Result: Pass
# Laura  - Score: nan  - Result: Fail
# </pre>
#
# </details>
